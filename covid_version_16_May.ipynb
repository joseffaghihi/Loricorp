# %% [markdown]
# <a href="https://colab.research.google.com/github/najafpour/COVIDUQTR/blob/main/covid_version_16_May.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
step1 = pd.read_excel('step1_seperate_depand_variable.xlsx')

# %%
step2 = pd.read_excel('step2_normalize+datacleaning.xlsx')

# %%
step3 = pd.read_excel('step3_interpolated.xlsx')

# %%
Bdedi_t2=[step2["Bdedi_t2"],step3["Bdedi_t2"]]
[step2["Bdedi_t2"].count(),step3["Bdedi_t2"].count()]
# Out:
# [313, 2985]

# %%
step2["Bdedi_t2"].plot()

# %%
for impacts in Bdedi_t2:
     timefilteredForce = plt.plot(impacts)

# %%
important_column = pd.read_excel('important_column.xlsx')
important_column
# Out:
#       Bdedi_t2  restriction_aliment_t2  ...  EPRies_t2  HSCies_t2
# 0          NaN                     NaN  ...        NaN        NaN
# 1          NaN                     NaN  ...        NaN        NaN
# 2          NaN                     NaN  ...        NaN        NaN
# 3          NaN                     NaN  ...        NaN        NaN
# 4          NaN                     NaN  ...        NaN        NaN
# ...        ...                     ...  ...        ...        ...
# 2986       6.0                     2.0  ...        4.5        3.0
# 2987       6.0                     2.0  ...        4.5        3.0
# 2988       6.0                     2.0  ...        4.5        3.0
# 2989       6.0                     2.0  ...        4.5        3.0
# 2990       6.0                     2.0  ...        4.5        3.0
#
# [2991 rows x 7 columns]

# %%
important_column.plot()

# %%
C = important_column.corr()
C
# Out:
#                           Bdedi_t2  ...  HSCies_t2
# Bdedi_t2                  1.000000  ...  -0.609863
# restriction_aliment_t2   -0.126830  ...   0.136622
# restriction_substance_t2 -0.079555  ...   0.218819
# Buedi_t2                  0.451136  ...  -0.512632
# BCCies_t2                -0.533254  ...   0.531952
# EPRies_t2                -0.443254  ...   0.504222
# HSCies_t2                -0.609863  ...   1.000000
#
# [7 rows x 7 columns]

# %%
sn.heatmap(C, annot=True)
plt.show()

# %%
D=C.abs()
sn.heatmap(D, annot=True)
plt.show()
