# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('1.xlsx')

# %%
df.plot(kind='scatter',x='Bdedi_t2',y='restriction_aliment_t2',color='red')
plt.show()

# %% [markdown]
# <h1> Column "changement_prod_t2" with missing data has 421 elements </h1>

# %%
df2=df["changement_prod_t2"]
df2.count()
# Out:
# 421

# %%
df2
# Out:
# 0       NaN
# 1       NaN
# 2       3.0
# 3       NaN
# 4       NaN
#        ...
# 2986    NaN
# 2987    NaN
# 2988    NaN
# 2989    NaN
# 2990    NaN
# Name: changement_prod_t2, Length: 2991, dtype: float64

# %%
plt.figure()
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df3=df2.interpolate()
df3
# Out:
# 0            NaN
# 1            NaN
# 2       3.000000
# 3       2.333333
# 4       1.666667
#           ...
# 2986    2.000000
# 2987    2.000000
# 2988    2.000000
# 2989    2.000000
# 2990    2.000000
# Name: changement_prod_t2, Length: 2991, dtype: float64

# %%
df3.count()
# Out:
# 2989

# %% [markdown]
# <h1> Column "changement_prod_t2" after interpolation has 2989 elements </h1>

# %%
plt.figure()
df3.plot()
# Out:
# <AxesSubplot:>

# %%
df4=df["2respect_lavage"]
df4.count()
# Out:
# 317

# %%
df4
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2986   NaN
# 2987   NaN
# 2988   NaN
# 2989   NaN
# 2990   NaN
# Name: 2respect_lavage, Length: 2991, dtype: float64

# %%
df4.plot();

# %%
df5=df4.interpolate()
df5.count()
# Out:
# 2985

# %%
df5
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2986    8.0
# 2987    8.0
# 2988    8.0
# 2989    8.0
# 2990    8.0
# Name: 2respect_lavage, Length: 2991, dtype: float64

# %%
df5.plot();

# %%
dff=df.interpolate()
df
# Out:
#         No  Code d'utilisateur  No Groupe  Consentement  genre   age  \
# 0        1             3387819        NaN           1.0    NaN   NaN
# 1        2             3387834        NaN           NaN    NaN   NaN
# 2        3             3387859        NaN           1.0    2.0  42.0
# 3        4             3387861        NaN           NaN    NaN   NaN
# 4        5             3387863        NaN           NaN    NaN   NaN
# ...    ...                 ...        ...           ...    ...   ...
# 2986  2987             3599981        NaN           NaN    NaN   NaN
# 2987  2988             3601069        NaN           NaN    NaN   NaN
# 2988  2989             3601323        NaN           NaN    NaN   NaN
# 2989  2990             3601340        NaN           NaN    NaN   NaN
# 2990  2991             3601546        NaN           NaN    NaN   NaN
#
#       situation_prof  niv_etude  perte_emploi  aide_fin_gouv  ...  Idedi_t2  \
# ...

# %%
dff
# Out:
#         No  Code d'utilisateur  No Groupe  Consentement  genre   age  \
# 0        1             3387819        NaN           1.0    NaN   NaN
# 1        2             3387834        NaN           1.0    NaN   NaN
# 2        3             3387859        NaN           1.0    2.0  42.0
# 3        4             3387861        NaN           1.0    2.0  38.0
# 4        5             3387863        NaN           1.0    2.0  34.0
# ...    ...                 ...        ...           ...    ...   ...
# 2986  2987             3599981        2.0           1.0    2.0  14.0
# 2987  2988             3601069        2.0           1.0    2.0  14.0
# 2988  2989             3601323        2.0           1.0    2.0  14.0
# 2989  2990             3601340        2.0           1.0    2.0  14.0
# 2990  2991             3601546        2.0           1.0    2.0  14.0
#
#       situation_prof  niv_etude  perte_emploi  aide_fin_gouv  ...  Idedi_t2  \
# ...

# %%
C=dff.corr()
C
# Out:
#                           No  Code d'utilisateur  No Groupe  Consentement  \
# No                  1.000000            0.912693  -0.110952           NaN
# Code d'utilisateur  0.912693            1.000000  -0.083076           NaN
# No Groupe          -0.110952           -0.083076   1.000000           NaN
# Consentement             NaN                 NaN        NaN           NaN
# genre              -0.258362           -0.201954   0.151774           NaN
# ...                      ...                 ...        ...           ...
# BCCies_t2           0.165783            0.111529  -0.413338           NaN
# TOTies_t2           0.000077            0.004541  -0.569009           NaN
# RESedeq_t2          0.021189            0.053272   0.446496           NaN
# Ecedeq_t2          -0.118774           -0.101977   0.624346           NaN
# OSA_t2.1            0.234967            0.291927   0.013842           NaN
#
#                        genre       age  situation_prof  niv_etude  \
# ...

# %%
sn.heatmap(C, annot=True)
plt.show()

# %%
D=C.abs()

# %%
dfff=pd.DataFrame(D)
dfff
# Out:
#                           No  Code d'utilisateur  No Groupe  Consentement  \
# No                  1.000000            0.912693   0.110952           NaN
# Code d'utilisateur  0.912693            1.000000   0.083076           NaN
# No Groupe           0.110952            0.083076   1.000000           NaN
# Consentement             NaN                 NaN        NaN           NaN
# genre               0.258362            0.201954   0.151774           NaN
# ...                      ...                 ...        ...           ...
# BCCies_t2           0.165783            0.111529   0.413338           NaN
# TOTies_t2           0.000077            0.004541   0.569009           NaN
# RESedeq_t2          0.021189            0.053272   0.446496           NaN
# Ecedeq_t2           0.118774            0.101977   0.624346           NaN
# OSA_t2.1            0.234967            0.291927   0.013842           NaN
#
#                        genre       age  situation_prof  niv_etude  \
# ...

# %%
dc = (dfff < 0.2) & (dfff < 1)
dc
# Out:
#                        No  Code d'utilisateur  No Groupe  Consentement  genre  \
# No                  False               False       True         False  False
# Code d'utilisateur  False               False       True         False  False
# No Groupe            True                True      False         False   True
# Consentement        False               False      False         False  False
# genre               False               False       True         False  False
# ...                   ...                 ...        ...           ...    ...
# BCCies_t2            True                True      False         False  False
# TOTies_t2            True                True      False         False   True
# RESedeq_t2           True                True      False         False   True
# Ecedeq_t2            True                True      False         False   True
# OSA_t2.1            False               False       True         False   True
#
# ...

# %%
dc.where(dc==False, 1)
# Out:
#                        No Code d'utilisateur No Groupe  Consentement  genre  \
# No                  False              False         1         False  False
# Code d'utilisateur  False              False         1         False  False
# No Groupe               1                  1     False         False      1
# Consentement        False              False     False         False  False
# genre               False              False         1         False  False
# ...                   ...                ...       ...           ...    ...
# BCCies_t2               1                  1     False         False  False
# TOTies_t2               1                  1     False         False      1
# RESedeq_t2              1                  1     False         False      1
# Ecedeq_t2               1                  1     False         False      1
# OSA_t2.1            False              False         1         False      1
#
# ...

# %%
def getIndexes(dfObj, value):
      
    # Empty list
    listOfPos = []
      
    # isin() method will return a dataframe with 
    # boolean values, True at the positions    
    # where element exists
    result = dfObj.isin([value])
      
    # any() method will return 
    # a boolean series
    seriesObj = result.any()
  
    # Get list of column names where 
    # element exists
    columnNames = list(seriesObj[seriesObj == True].index)
     
    # Iterate over the list of columns and
    # extract the row index where element exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
  
        for row in rows:
            listOfPos.append((row, col))
              
    # This list contains a list tuples with 
    # the index of element in the dataframe
    return listOfPos
  
# Calling getIndexes() function to get 
# the index positions of all occurrences
# of 22 in the dataframe

# %%
listOfPositions = getIndexes(dc,1)
  
print('Index positions of 1 in Dataframe : ')
  
# Printing the position
keep_columns = set()
for i in range(len(listOfPositions)):
    keep_columns.add(listOfPositions[i][0])
    keep_columns.add(listOfPositions[i][1])
print( keep_columns)
len(keep_columns)
# Out:
# Index positions of 1 in Dataframe :
# ...

# %%
sub_df = dff[[f for f in keep_columns]]

# %%
sub_df
# Out:
#       No Groupe  2nbr_amis  2edeq13  2eed1  2ies10  2ies17  1act_phys3_intens  \
# 0           NaN        NaN      NaN    NaN     NaN     NaN                NaN
# 1           NaN        NaN      NaN    NaN     NaN     NaN                NaN
# 2           NaN        NaN      NaN    NaN     NaN     NaN                NaN
# 3           NaN        NaN      NaN    NaN     NaN     NaN                NaN
# 4           NaN        NaN      NaN    NaN     NaN     NaN                NaN
# ...         ...        ...      ...    ...     ...     ...                ...
# 2986        2.0        3.0     10.0    3.0     1.0     5.0                3.0
# 2987        2.0        3.0     10.0    3.0     1.0     5.0                3.0
# 2988        2.0        3.0     10.0    3.0     1.0     5.0                3.0
# 2989        2.0        3.0     10.0    3.0     1.0     5.0                3.0
# 2990        2.0        3.0     10.0    3.0     1.0     5.0                3.0
#
# ...

# %%
from sklearn import svm
Svc_classifier = svm.SVC(kernel = 'rbf', gamma =‘auto’,C = C).fit(X, y)
# Out:
#   File "<ipython-input-133-3412a151bf39>", line 2
#     Svc_classifier = svm.SVC(kernel = 'rbf', gamma =‘auto’,C = C).fit(X, y)
#                                                          ^
# SyntaxError: invalid character in identifier
